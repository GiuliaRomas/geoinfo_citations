# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

# %%
import pandas as pd
df = pd.read_csv(ROOT / "data/processed/citacoes_geoinfo.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   titulo_original     75 non-null     str
#  1   ano_original        75 non-null     int64
#  2   titulo              0 non-null      float64
#  3   ano                 0 non-null      float64
#  4   autores             0 non-null      float64
#  5   instituicoes        0 non-null      float64
#  6   idioma              0 non-null      float64
#  7   pais                0 non-null      float64
#  8   veiculo_publicacao  0 non-null      float64
#  9   doi                 0 non-null      float64
#  10  url                 0 non-null      float64
# dtypes: float64(9), int64(1), str(1)
# memory usage: 6.6 KB
